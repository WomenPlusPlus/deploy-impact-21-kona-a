# %% [markdown]
# <a href="https://colab.research.google.com/github/WomenPlusPlus/deploy-impact-21-kona-a/blob/add_analysis/kona-app/data/data_transformation/01_Filter_Groups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook filters the data in the SubTargetGroup column. The purpose of doing this is to have quick access buttons for various types of users on the home screen. For instance, if a User is a refugee or a student, they can click the corresponding button and see all organizations that offer sercives in these areas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Open the csv file

# %%
df = pd.read_csv("sub_categories_orgs.csv")
df
# Out:
#     ID  ...       Region
# 0    1  ...  Saint-Louis
# 1    2  ...  Saint-Louis
# 2    3  ...        Dakar
# 3    4  ...        Dakar
# 4    5  ...        Dakar
# ..  ..  ...          ...
# 57  58  ...        Dakar
# 58  59  ...        Dakar
# 59  60  ...        Dakar
# 60  61  ...        Dakar
# 61  62  ...  Saint-Louis
#
# [62 rows x 13 columns]

# %% [markdown]
# ## Change the column name to be pythonic

# %%
# Change column name
df['SubTargetGroup'] = df['Sub Target Group']

# %% [markdown]
# ###  Create function that splits the list of sub categories into strings. Then count how many times the word appears
#
# This function is useful for finding synonyms that can be grouped together, and for finding misspelled words since I am a terrible speller

# %%
def count_frequency(col_name):
  df2 = col_name
  df2_split = df2.str.split(",")
  word_freq = {} 
  for row in df2_split:
    for word in row:
        word_trimmed = word.strip() 
        if (word_trimmed in word_freq): 
            word_freq[word_trimmed] += 1
        else: 
            word_freq[word_trimmed] = 1
  s = pd.Series(word_freq, name='Count')
  s.index.name = "Category"
  s = s.sort_values(ascending=False)
  print(s)

# %% [markdown]
# ## Copy the dataframe. In order to use the function above, the list must be a string

# %%
df2 = df
df2["SubTargetGroup"] = df2["SubTargetGroup"].astype(str)

# %%
sub_cat_df = df2['SubTargetGroup']
count_frequency(sub_cat_df)

# %% [markdown]
# ## Filter the data based on the results that were found in the function

# %%
import re
# Remove additional groups
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace(', other people looking for training/education/exchange ?','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('(Professionals: Researchers)','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('?','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace(', Ngos looking for training/engineering','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Impoverished peoples','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Nature,','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('( especially birds)','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('( especially birds)','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('\(\)','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('wildlife, and human-made systems that interact with/endager birds and their protection','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Researchers in the TIC field','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('NGO and development actors','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Youth','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Communities','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('At Risk','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('looking for work','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Journalists','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Health workers','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Health Organizations','', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Internationals','', regex=True)


# Correct spelling and Capatilization 
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('abuse','Abuse,', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('violence','Violence', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('PregnantVictims','Pregnant Victims', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Victims of human trafficking','Victims of Human Trafficking', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('vulnerable','Vulnerable', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('At risk youth','At Risk Youth', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Victims of domestic Violence','Victims of Domestic Violence', regex=True)



# Orphans 
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Homeless Children','Orphans', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Homeless children','Orphans', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Unhoused children','Orphans', regex=True)

# Refugees
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Migrants','Refugees', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Migrant','Refugees', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Relocated Populations','Refugees', regex=True)

# Rural

df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('People in the rural areas','Rural', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Rural Community','Rural', regex=True)

# Farmers
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Victims of human trafficking','Victims of Human Trafficking', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('farmers','Farmers', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Farmer','Farmers', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Farmerss','Farmers', regex=True)

# Mothers
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Pregnant Women','Pregnant', regex=True)

# Homeless People
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Unhoused','Homeless', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Homeless People','Homeless', regex=True)


#df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Homeless','Homeless People', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Incarcerated','Prisoners', regex=True)

# Students
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('African Students','Students', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('International students','Students', regex=True)


# Violence
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Vunerable','Vulnerable', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Pregnant Victims of Domestic Violence','Victims of Domestic Violence', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Vunerable Children','Vulnerable', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Victims of Domestic Violence','Domestic Violence', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Women victims','Victims of Violence', regex=True)
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace('Vulnearble Children','Vulnerable', regex=True)

# %%
df2['SubTargetGroup'] = df2.SubTargetGroup.str.replace(r'(?:\s|^)nan(?:,\s|$)','', regex=True)

# %%
sub_cat_df = df2['SubTargetGroup']
count_frequency(sub_cat_df)
# Out:
# Category
#                                   31
# Vulnerable                        22
# Refugees                           8
# Farmers                            7
# Orphans                            6
# Disabled                           6
# Victims of Violence                5
# Professionals                      4
# Entrepreneurs                      4
# Rural                              4
# Victims of Human Trafficking       4
# Students                           3
# Asylum Seekers                     2
# Prisoners                          2
# Victims of Abuse                   2
# Domestic Violence                  2
# Homeless                           2
# Pregnant                           1
# People with drug addictions        1
# LGBT                               1
# Young parents                      1
# Young girls                        1
# Young unmarried mothers            1
# Victims of sexual exploitation     1
# Name: Count, dtype: int64

# %% [markdown]
# ## Save the data file

# %%
df2.to_csv('edited_subcategories.csv', index=False)

# %%
df3 = pd.read_json("/content/edited_orgs24.11.json")
df3
# Out:
#     ID  ...       Region
# 0    1  ...  Saint-Louis
# 1    2  ...  Saint-Louis
# 2    3  ...        Dakar
# 3    4  ...        Dakar
# 4    5  ...        Dakar
# ..  ..  ...          ...
# 57  58  ...        Dakar
# 58  59  ...        Dakar
# 59  60  ...        Dakar
# 60  61  ...        Dakar
# 61  62  ...  Saint-Louis
#
# [62 rows x 13 columns]

# %% [markdown]
# # JSON Sub Category Editing starts here

# %%
pd.set_option('display.max_rows', None)
df3["SubCategory"] = df3["SubCategory"].astype(str)

sub_cat_df2 = df3['SubCategory']
count_frequency(sub_cat_df2)
# Out:
# Category
#                                           16
# Food                                      14
# Entrepreneurship                           8
# Partnerships                               7
# Children's Rights                          7
# Shelter                                    6
# Training                                   5
# Water                                      5
# Leadership Training                        5
# Protection                                 5
# Financial Services                         4
# Financial Support                          4
# Mental Health                              4
# Victim of Violence                         4
# HIV/AIDS                                   4
# Human Rights                               3
# Citizenship                                3
# Reintegration                              3
# Sanitation                                 3
# Child Protection                           3
# Maternal                                   3
# ...

# %% [markdown]
# # New Section
